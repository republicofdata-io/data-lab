# %% [markdown]
# # [Tutorial Title]
#
# **Data Lab** | [RepublicOfData.io](https://republicofdata.io)
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/republicofdata-io/data-lab/blob/main/tutorials/YOUR-NOTEBOOK.ipynb)
#
# ---
#
# [One-sentence description of what this tutorial teaches. Max 100 characters.]
#
# **Related Data Report:** [Link to the Data Report story that inspired this tutorial]

# %% [markdown]
# ## Setup
#
# Run the cell below to install required dependencies. All versions are pinned to ensure reproducibility.

# %%
# Install dependencies with pinned versions
# Replace with actual packages needed for your tutorial
# !pip install -q pandas==2.0.3 numpy==1.24.3

# Verify installation
import pandas as pd
import numpy as np
print(f"pandas: {pd.__version__}")
print(f"numpy: {np.__version__}")

# %% [markdown]
# ## Introduction
#
# ### What You'll Learn
#
# - [Learning objective 1]
# - [Learning objective 2]
# - [Learning objective 3]
#
# ### Prerequisites
#
# - **Difficulty:** [Beginner / Intermediate / Advanced]
# - **Time:** [15-30] minutes
# - **Requirements:** [e.g., Basic Python familiarity, no prior experience needed]
#
# ### Overview
#
# [2-3 sentences explaining the context and why this matters for data product builders.]

# %% [markdown]
# ---
#
# ## 1. [First Section Title]
#
# [Explain what this section covers and why it's important.]

# %%
# Section 1 code
# Each code cell should accomplish ONE clear task
# Add comments explaining what the code does

print("Section 1 complete!")

# %% [markdown]
# ---
#
# ## 2. [Second Section Title]
#
# [Explain what this section covers and builds on from section 1.]

# %%
# Section 2 code
# Build on concepts from section 1

print("Section 2 complete!")

# %% [markdown]
# ---
#
# ## 3. [Third Section Title]
#
# [Explain the final piece that brings everything together.]

# %%
# Section 3 code
# Bring concepts together into a working example

print("Section 3 complete!")

# %% [markdown]
# ---
#
# ## Summary
#
# ### What You Built
#
# [Describe the concrete artifact or capability the reader now has.]
#
# ### Key Takeaways
#
# 1. [Key concept 1]
# 2. [Key concept 2]
# 3. [Key concept 3]
#
# ### Your Code
#
# You can save this notebook to your Google Drive or download it to adapt for your own projects.

# %% [markdown]
# ---
#
# ## Next Steps
#
# ### Related Tutorials
#
# - [Link to related Data Lab tutorial 1]
# - [Link to related Data Lab tutorial 2]
#
# ### Further Reading
#
# - [Original Data Report story](link)
# - [External resource 1]
# - [External resource 2]
#
# ### Questions or Feedback?
#
# Visit [RepublicOfData.io](https://republicofdata.io) or reply to the Data Report newsletter.
#
# ---
#
# *Template version: 1.0 | Data Lab by RepublicOfData.io*
